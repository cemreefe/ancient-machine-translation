# %%
import numpy as np
import time
import pandas as pd
from datetime import datetime

# %%
from bs4 import BeautifulSoup
from bs4 import element
import urllib
import re

html_page = urllib.request.urlopen("http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=all#")
soup = BeautifulSoup(html_page)

# %%
link_list = []

for link in soup.findAll('a'):
    link_list.append(link.get('href'))

# %%
pref = "http://etcsl.orinst.ox.ac.uk/cgi-bin/"
paired_links = []

for i in range(len(link_list)-1):
    if "text=c" in link_list[i] and "text=t" in link_list[i+1]:
        paired_links.append(pref + link_list[i])
        paired_links.append(pref + link_list[i+1])

# %%
link_pairs = np.reshape(np.array(paired_links), (-1,2))

# %%
# first parse translation to understand what sentences should be concatenated.

tips = []

# http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.2&display=Crit&charenc=gcirc#

for i in range(len(link_pairs)):  
    
    print(i, "\t", link_pairs[i][0])
    html_page = urllib.request.urlopen(link_pairs[i][0])
    soup = BeautifulSoup(html_page, "xml") # "xml" parser is significantly faster but freezes.
    
    for span in soup.findAll('span'):
        tip = span.get('onMouseover')
        if not tip == None:
            tip = tip[18:-2]
            tip = re.sub("<sub>|</sub>", "", tip)
            tip = re.sub(" \(.*\) ", ";", tip)
            tip = re.sub(";to be ", ";", tip)
            tip = re.sub(";to ", ";", tip)
            tip = re.sub("soothing expression", "oh", tip)
            tip = re.sub("\?", "", tip)

            ## information loss
            tip = re.sub(" *\(.+\)", "", tip)
            
            tips.append(tip)
    
    if i%3 == 2:
        print("i sleep")
        time.sleep(10)

print("{}\ttokens".format(len(tips)))
unique_tips = np.unique(tips)
print("{}\tunique tokens".format(len(unique_tips)))

## Inspect this closer to remove unwanted pairs.

unique_pairs = [i.replace('', '').split(";") for i in unique_tips]

# If RHS has "," then split RHS and add both parts as different pairs
for pair in unique_pairs:
    if len(pair)!=2:
        unique_pairs.remove(pair)
    elif "," in pair[1]:
        rhs = pair[1].split(", ")
        unique_pairs.append([pair[0], rhs[0]])
        unique_pairs.append([pair[0], rhs[1]])
        unique_pairs.remove(pair)
        
now   = datetime.now() # current date and time
stamp = now.strftime("%Y%m%d%H%M")        

pd.DataFrame(unique_pairs).to_csv("data/unique_tip_pairs_all.csv", ";", index=None, header=["akk", "en"])
# Out:
# 0 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.1&display=Crit&charenc=gcirc
# 1 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.2&display=Crit&charenc=gcirc
# 2 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.3&display=Crit&charenc=gcirc
# i sleep
# 3 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.4&display=Crit&charenc=gcirc
# 4 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.2.1&display=Crit&charenc=gcirc
# 5 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.2.2&display=Crit&charenc=gcirc
# i sleep
# 6 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.3.1&display=Crit&charenc=gcirc
# 7 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.3.2&display=Crit&charenc=gcirc
# 8 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.3.3&display=Crit&charenc=gcirc
# i sleep
# 9 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.3.4&display=Crit&charenc=gcirc
# ...

# %%
#pd.read_csv("data/unique_tip_pairs_all.csv", ";").to_numpy()

# %%
link_pairs
# Out:
# array([['http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.1&display=Crit&charenc=gcirc',
#         'http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=t.1.1.1'],
#        ['http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.2&display=Crit&charenc=gcirc',
#         'http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=t.1.1.2'],
#        ['http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.3&display=Crit&charenc=gcirc',
#         'http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=t.1.1.3'],
#        ['http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.4&display=Crit&charenc=gcirc',
#         'http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=t.1.1.4'],
#        ['http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.2.1&display=Crit&charenc=gcirc',
#         'http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=t.1.2.1'],
#        ['http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.2.2&display=Crit&charenc=gcirc',
# ...

# %%
#for i in range(len(link_pairs)):  
i=0

nums = []

print(i, "\t", link_pairs[i][1])
html_page = urllib.request.urlopen(link_pairs[i][1])
soup = BeautifulSoup(html_page, "xml") # "xml" parser is significantly faster but freezes.

for a in soup.findAll("a"):
    c = a.contents
    if len(c) != 0:
        if c[0].isdigit:
            nums.append(c)
# Out:
# 0 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=t.1.1.1

# %%
nums
# Out:
# [['1-4.'],
#  ['5-10.'],
#  ['11-16.'],
#  ['17-19.'],
#  ['20-26.'],
#  ['27-28.'],
#  ['29-32.'],
#  ['33-39.'],
#  ['40-43.'],
#  ['44-49.'],
#  ['49A-49P.'],
#  ['49Q-49V.'],
#  ['50-54.'],
#  ['55-62.'],
#  ['63-68.'],
#  ['69-74.'],
#  ['75-87.'],
#  ['88-96.'],
#  ['97-107.'],
#  ['108-116.'],
#  ['117-126.'],
#  ['126A-126K.'],
#  ['126L-126Q.'],
#  ['126R-126CC.'],
#  ['127-146.'],
#  ['147-151.'],
#  ['152-158.'],
#  ['159-166.'],
#  ['167-177.'],
#  ['178-185.'],
#  ['186-189.'],
#  ['190-197.'],
#  ['198-201.'],
#  ['202-210.'],
#  ['211-219.'],
#  ['220-227.'],
#  ['228-234.'],
#  ['235-246.'],
#  ['247-253.'],
#  ['254-263.'],
#  ['264-271.'],
#  ['272-280.'],
#  ['281.']]

# %%
# Returns True if given "num", line number is between a given line number range.
# Takes into consideration the line numbers that end in letters, i.e. "49A-49J."

def lesstoe(ran, num):
    
    if len(re.findall(r"[0-9]*-?[0-9]*\.", ran)) == 0 or len(re.findall(r"[0-9]*\.", num)) == 0:
        return True
    
        
    offset = 54
    
    ran = ran[:-1]
    
    if num == "":
        num = "p"
    
    if not num[0].isdigit():
        num = "0."
        
    num = num[:-1]
    
    drange = ran.split("-")
    
    
    if len(drange) == 2:
        drange.append(num)
        

        for i in range(3):
            
            if len(drange[i])>2:
                if drange[i][-2].isalpha():
                    drange[i] = drange[i][:-2] + "." + repr(9) + drange[i][-1]
                    drange[i] = drange[i][:4] + re.sub("\.", "", drange[i][4:])
            
            if len(drange[i])>1:
                if drange[i][-1].isalpha():
                    drange[i] = re.sub(drange[i][-1], "." + repr(ord(drange[i][-1])-offset),drange[i])
                    drange[i] = drange[i][:4] + re.sub("\.", "", drange[i][4:])

                    
        print(drange)
        return (float(drange[2]) <= float(drange[1])) or float(drange[2]) == 0

    else:
        print(drange)
        return ran != num

# %%
conts_list     = []
sentences_list = []
ltrs_list      = []


# j=0 works for now

for j in range(3): #range(len(link_pairs)):  
    

    #translation

    conts = []
    
    print(j, "\t", link_pairs[j][1])
    html_page = urllib.request.urlopen(link_pairs[j][1])
    soup = BeautifulSoup(html_page, "xml") # "xml" parser is significantly faster but freezes.

    for a in soup.findAll("p"):
        c = a.contents
        if len(c) != 0:
            for i in range(len(c)):
                if type(c[i]) is element.Tag:
                    c[i] = "".join(c[i].contents)
            conts.append(c)

    for i in range(len(conts)):
        conts[i][1] = "".join(conts[i][1:])
        conts[i][1] = re.sub("\(.*?\)", "", conts[i][1])
        conts[i][1] = re.sub("  ", " ", conts[i][1])
        del conts[i][3:]

    del conts[-1]



    ## transliteration

    ltrs = []

    print(j, "\t", link_pairs[j][0])
    html_page = urllib.request.urlopen(link_pairs[j][0])
    soup = BeautifulSoup(html_page, "xml") # "xml" parser is significantly faster but freezes.

    for a in soup.findAll("td"):
        c = a.contents
        if len(c) != 0:
            for i in range(len(c)):
                if type(c[i]) is element.Tag:
                    s = str(c[i])

                    s = re.sub("<span onMouseover.*?;", "", s)

                    s = re.sub(" -- ", " ", s)
                    s = re.sub("<phr.*/phr>", "", s)
                    s = re.sub("<font.*/font>", "", s)
                    s = re.sub("<a.*?>|</a>", "", s)
                    s = re.sub("<img.*?>", "", s)
                    s = re.sub("\n", "", s)
                    s = re.sub("<span.*?>|</span>", "", s)
                    s = re.sub("<sup>", "^", s)
                    s = re.sub("</sup>", "-", s)
                    s = re.sub("<sub>|</sub>", "", s)

                    c[i] = s
        ltrs.append(c)

    for i in range(len(ltrs)):
        ltrs[i] = "".join(ltrs[i])


    ## concatenated transliterations



    k = 0

    l = len(ltrs)
    
    sentences = []

    for ran in nums:

        ran =  ran[0]

        sentence = ""

        while(k<l-1 and lesstoe(ran, ltrs[k])):
            sentence += ltrs[k+1]
            k+=1
        print(len(sentences))
            
        sentences.append(sentence)


    if len(conts) != len(sentences):
        print("ERROR NO:7 \"Somethings wrong I can feel it\"")

    
    for i in range(len(conts)):
        conts[i][2] = sentences[i]

    ltrs_list.append(ltrs)
    conts_list.append(conts)
    sentences_list.append(sentences)
# Out:
# 0 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=t.1.1.1
# 0 	 http://etcsl.orinst.ox.ac.uk/cgi-bin/etcsl.cgi?text=c.1.1.1&display=Crit&charenc=gcirc
# ['1', '4', '1']
# ['1', '4', '2']
# ['1', '4', '3']
# ['1', '4', '4']
# ['1', '4', '5']
# 0
# ['5', '10', '5']
# ['5', '10', '6']
# ['5', '10', '7']
# ['5', '10', '8']
# ['5', '10', '9']
# ['5', '10', '10']
# ['5', '10', '11']
# 1
# ['11', '16', '11']
# ['11', '16', '12']
# ['11', '16', '13']
# ['11', '16', '14']
# ['11', '16', '15']
# ['11', '16', '16']
# ['11', '16', '17']
# 2
# ['17', '19', '17']
# ['17', '19', '18']
# ['17', '19', '19']
# ['17', '19', '20']
# 3
# ['20', '26', '20']
# ['20', '26', '21']
# ['20', '26', '22']
# ['20', '26', '23']
# ['20', '26', '24']
# ['20', '26', '25']
# ['20', '26', '26']
# ['20', '26', '27']
# 4
# ['27', '28', '27']
# ['27', '28', '28']
# ['27', '28', '29']
# 5
# ['29', '32', '29']
# ['29', '32', '30']
# ['29', '32', '31']
# ['29', '32', '32']
# ['29', '32', '33']
# 6
# ['33', '39', '33']
# ...

# %%
p = 0
print(len(conts_list[p]), len(sentences_list[p]))
# Out:
# 43 43

# %%
conts_list[0]
# Out:
# [['1-4.',
#   ' Pure are the cities -- and you are the ones to whom they are allotted. Pure is Dilmun land. Pure is Sumer -- and you are the ones to whom it is allotted. Pure is Dilmun land. Pure is Dilmun land. Virginal is Dilmun land. Virginal is Dilmun land. Pristine is Dilmun land.',
#   '1. iri^ki- kug-kug-ga-am3 e-ne ba-am3-me-en-ze2-en kur dilmun^ki- kug-ga-am3 2. ki-en-gi kug-ga e-ne ba-am3-me-en-ze2-en kur dilmun^ki- kug-ga-am3 3. kur dilmun^ki- kug-ga-am3 kur dilmun sikil-am3 4. kur dilmun^ki- sikil-am3 kur dilmun^ki- dadag-ga-am3 5.'],
#  ['5-10.',
#   ' He laid her down all alone in Dilmun, and the place where Enki had lain down with his spouse, that place was still virginal, that place was still pristine. He laid her down all alone in Dilmun, and the place where Enki had lain down with Ninsikila, that place was virginal, that place was pristine.',
# ...

# %%
len(conts_list[2])
# Out:
# 43

# %%
i = 0

# %%
ltrs
# Out:
# ['',
#  '',
#  '',
# ...
